# %%
# Need to fix the import of environment variable in a notebook
# from drawinganalyses.config import LOCAL_DATA_DIR
from drawinganalyses.datasets.drawing import Drawing
from drawinganalyses.datasets.drawings_pytorch import DrawingDataset
from pathlib import Path
from tensorflow import keras

LOCAL_DATA_DIR = Path("/home/emaitre/MADE/molly-humains/")

# %%
annotations_file = "labels.csv" 
dataset_name = 'Artistanimals'
label_to_str = {0: 'Molly', 1: 'Pigcasso', 2: 'Pocketswarhol'}

# %%
drawings = DrawingDataset(data_dir=LOCAL_DATA_DIR, dataset_name=dataset_name, annotations_file=annotations_file, label_to_str=label_to_str)

# %%
drawings.show(1500)
# Out:
#                                            name  label
# 0                 Wintermolly20080216000001.jpg      0
# 1                 Springmolly20100414000001.jpg      0
# 2                 Wintermolly20090115000001.jpg      0
# 3                 Springmolly20090521000001.jpg      0
# 4                 Autumnmolly20061218000002.jpg      0
# ...                                         ...    ...
# 1594  AD7D4C1E-5527-49AF-964F-66A3255FAC56.jpeg      2
# 1595                                Nirvana.jpg      2
# 1596  C4352CFB-BB55-4236-B1F7-691A26B194D4.jpeg      2
# 1597  C1CEECF5-8A03-4E03-8E80-3AE3B3CAE758.jpeg      2
# 1598  2F3D6AE0-E3A7-42BC-93E1-E9A7AD80DDC5.jpeg      2
#
# [1599 rows x 2 columns]
# <PIL.Image.Image image mode=RGB size=300x225>
# 'Drawing name : D7A47085-65C5-4DD6-B2CB-21B354958035.jpeg, label : Pocketswarhol'
